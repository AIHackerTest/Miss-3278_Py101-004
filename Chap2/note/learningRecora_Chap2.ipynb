# %% [markdown]
# ## 170820-170826 [2w]Chap2 learning record
#
# ### 170820 [2w0d]
#
# * AM 8：00 - 10：30 开始用 python3 改写 ["笨办法"学Python](https://book.douban.com/subject/26264642/) ex43 的内容。完成！
# * PM 10：00 - 10：30 浏览 Chap2 课程卡片。又是一片混沌 API ？ JSON ？
#
# 感受：体会「自顶而下」的编程过程，程序不复杂，检查的过程中发现一些小问题，都解决了。能够稍微看懂这个练习。
#
# ### 170821 [2w1d]
#
# * AM 5：00 - 7：00 把 Chap2 卡片中的网页都浏览一遍。
# * PM 7：30 - 10：30 继续浏览网页，看了 API 和 JSON， 但还是没懂 API 怎么接入。
#
#  做法： 找了一堆将 API 及其使用的网页，留明天早晨学习。
#
# ### 170822 [2w2d]
#
# * AM 5：20 - 7：00 学习昨天晚上找到的网页上的例子，这次不是看，是写代码，看结果，帮助自己明白 API 到底怎么用，是怎么一会儿事儿。输出了一个学习的文档。
# * PM 7：00 - 8：40 把早晨遗留的一些问题做了补充，并开始写 Chap2 的任务，在 Chap1 的基础上做了 API 查询天气的修改。
#  （中间插播了阳老师的直播，哎呀，很多都没听懂，再加上阳老师的操作根本看不清，还有很长的路要走……）
# * PM 10：00 - 10：40 继续修改 Chap2 任务，让它能够运行，遇到了 keyEorro， 留作明天早晨的任务。
#
#    做法：小规模调式，然后再放到大程序中运行，不好使再找问题。
#
#
# ### 170823 [2w3d]
#
# * AM 5：35 - 7：00 找 keyError 的问题，然后加上 quit，help 和 history 的调用，基本完成程序。打算晚上加上 try 语句。
# * PM 4：00 - 6：30 提交作业。
#
#  感受：已经适应了报错机制，报错问题小解决时间少，报错问题大解决时间长，但总之，不用焦虑，也没有厌倦，这是正常情况啊，哈哈！
#
#  做法：
#
#   1. keyError. 发现数据返回 JSON 类型之后，如果输入的城市不在 json['results'] 中，则报错 keyError: 'results'。
#
#     1) 查看城市不在 json['results'] 中的返回内容，发现返回的是不同版本的报错。上心知天气 API 官网，看说明，总结，所有“查无此城”返回 json['status']
#
#     2) 使用 if 条件语句一步步测试  json['status']，help, history 和quit，最后程序基本完成。
#
# ### 170824 [2w4d]
#
# * AM 没起来
# * PM 6：00 - 7：00 看了看之前积累的网页内容。
#
#   感受：一天没怎么学，有点儿自责！
#
# ### 170825 [2w5d]
#
# * AM 5：30 - 7：00 看到小组内 issue [[Share]程序说明&字符流程图画法分享 · Issue #78 · AIHackers/Py101-004](https://github.com/AIHackers/Py101-004/issues/78) 浏览阅读，阳老给了一篇文档 [Readme Driven Development](http://tom.preston-werner.com/2010/08/23/readme-driven-development.html)
# * PM 下午一直在思考 NBR 帖子的内容，还有阳老师这周在部落的答疑。因工作回家晚，直接睡觉！
#
#   感受：
#   1. 因我在任务中写到“程序使用说明：…… 这个一直不知道改写啥”，@NBR-hugh 开了一个帖子来讨论分析，很感谢能写这个 issue，不仅把问题拎出来，还把「坏思维」习惯也拎了出来。他的帖子分析了这个问题存在的心态：
#
#             个人推测来自对自己行为的判定
#                以做练习,交作业的学生心态来对待
#             而不是
#                我是在开发一个真正可以发布,可以使用的产品.
#
#      开始，我是本能的不太同意这个推测的，认为自己是内在动机驱使来学习，怎么会是单纯地以完成任务，交作业的心态来对待呢，我还想学以致用，最起码能写出一个应用产品让我现在的工作变得高效！继续思考，「完成任务、交作业」不是我的心态，而是我的思维和行为本身。**并不是有内在动机就能够有正确行为。** 人的行为方式一旦成为习惯很难被察觉和改变，我确实在交作业之后松懈一些。如果按照 @NBR-hugh 所说反过来思考「我在开发一个真正可以发布并使用的产品」，这一部分是必须要解决的问题，我想我还会像做任务的时候一样，想方设法……
#
#      这周阳老在部落里说：**习惯比目标更重要。** 还讲了量级思考法，以前在阳老的文章当中也看过，但是都不太会用，狭隘地理解到「取其上者，得其中」的层次……结合 @NBR-hugh 的帖子，是要有意识地克服之前的坏习惯，建立更高层次的思维方式和行为习惯。这都是部落里倡导的，只不过没有这次深有体会，又一次见证了「视而不见听而不闻学而不用」的坏习惯，感谢 @NBR-hugh！
#
#    2. 读了 [Readme Driven Development](http://tom.preston-werner.com/2010/08/23/readme-driven-development.html) 对 Readme 有了更好的理解。写在项目之前，对项目有一个总体的思路不至于跑偏，更加方便中途有人参与时更多的解释。
#
# ### 170826 [2w6d]
#
# * AM 7：00 - 10：00 (中间吃饭半小时) 学习["笨办法"学Python (豆瓣)](https://book.douban.com/subject/26264642/) 中 ex44 - ex46 部分，并完成 ex46, 还需要看 nose, distibute, virtualenv 的说明。
